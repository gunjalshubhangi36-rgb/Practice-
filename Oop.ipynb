# %% [markdown]
# create class

# %%
class car:      #create class
    pass

    def greet():      #method
       print("Hello")

obj = car
obj.greet()          #create object of class
# Out:
# Hello

# %% [markdown]
# Constructor

# %%
class car:
    def __init__(self, color, name, price, milage):
        self.color = color
        self.name = name
        self.price = price
        self.milage = milage

    def display(self):
        print(self.name)
        print(self.color)
        print(self.price)
        print(self.milage)

obj = car("Black","BMW",100000,23)
obj.display()
# Out:
# BMW
# Black
# 100000
# 23

# %%
class car:
    def __init__(self, color, name, price, milage):   #self is used to store current value
        self.color = color
        self.name = name
        self.price = price
        self.milage = milage

    def display(self):
        print(self.name)
        print(self.color)
        print(self.price)
        print(self.milage)


color = input("Enter Color")
name = input("Enter Name")
price = input("Enter price")
milage = input("Enter Milage")

obj = car(color, name, price, milage)
obj.display()
# Out:
# BMW
# Black
# 10
# 15

# %% [markdown]
# Pasacal Case

# %%
class Std_Data: # pasacalcase
    pass

# %% [markdown]
# Snak Case

# %%
std_name = "demo user"
print(std_name)

# %% [markdown]
# Constant value

# %%
ACC_NUM = 1020   #constat value it is write in upper case

# %%
_acc_num_ = 10202980 #private variable it is used make it private

# %%
list_one = [1,2,3]
list_two = [4,5,6]

list_3 = list_one + list_two
print(list_3)

nums = len(list_3)

if nums % 2 == 1:   
    res = list_3[nums // 2]
    print(res)
else: 
    #res = list_3[nums // 2 - 1], list_3[nums // 2]                
    num1 = list_3[nums // 2 - 1] 
    num2 = list_3[nums // 2]

    add = num1 + num2
    res = add / 2
    print(res)
# Out:
# [1, 2, 3, 4, 5, 6]
# 3.5

# %%
class Bank_Atm:

    def __init__(self):
        pass

    def menu(self):
        print("1. Enter 1 to set pin: ")
        print("2. Enter 2 to chack balance: ")
        print("3. Enter 3 to deposit moeny: ")
        print("4. Enter 4 to Withdraw moeny: ")
        print("5. Enter 5 to change pin: ")
        print("6. Enter 6 to Exit: ")
obj = Bank_Atm()
obj.menu()
# Out:
# 1. Enter 1 to set pin:
# 2. Enter 2 to chack balance:
# 3. Enter 3 to deposit moeny:
# 4. Enter 4 to Withdraw moeny:
# 5. Enter 5 to change pin:
# 6. Enter 6 to Exit:

# %% [markdown]
# str 1 = "Demo User 1 Demo"
# str 2 = "Demo "
#
# find the index of the demo in the first string starting and ending index

# %%
str1 = "demo user 1 demo"
str2 = "demo"

str1 = str1.split()

print("Found the str2 in srt1: ", str1.index(str2))

# if str2 in str1:
#     for i in range(len(str1)):
#         if str1[i: i + len(str2)]==str2:
#             print(i)
# else:
#     print("String is not in str1")
# Out:
# Found the str2 in srt1:  0
