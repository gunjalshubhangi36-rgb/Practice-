# %% [markdown]
# 8. Given two strings, find the common characters using sets.

# %%
str1 = "Shubahgni"
str2 = "Gunjal"

set1 = set(str1)
set2 = set(str2)

print(set1 & set2)
# Out:
# {'a', 'n', 'u'}
