# %% [markdown]
# 9. Given multiple lists, find all elements that appear in every list using sets.

# %%
list1 = [1, 2, 7, 8]
list2 = [5, 6, 7, 8]
list3 = [4, 7, 3, 8]

set1 = set(list1)
set2 = set(list2)
set3 = set(list3)

print(set1 & set2 & set3)
# Out:
# {8, 7}
