# %%
age = 20

if age >= 18:
    print("You are eligible to vote")
else:
    print("You are not eligible to vote")
# Out:
# You are eligible to vote

# %%
marks = 85

if marks >= 75:
    print("Grad A")
elif marks >= 55:
    print("Grad B")
elif marks >= 35:
    print("Grad C")

else:
    print("Fail")
# Out:
# Grad A

# %%
grade = "A"

match grade:

    case "A":
        print("Marks is above 75")

    case "B":
        print("Marks is above 55")

    case "C":
        orint("Marks id above 35")

    case _:
        print("fail")
# Out:
# fail

# %%
age = 20
nationality = "Indian"
if age >= 18:

    if nationality == "Indian":
        print("You are eligible to vote")
    else:
        print("You are not eligible to vote")

else:
    print("Age is not 18")
# Out:
# You are eligible to vote

# %% [markdown]
# same as if else but write in only one line #Turnary operator

# %%
age = 20
print("eligible for vote") if age>= 18 else print("not eligible for vote")
# Out:
# eligible for vote
