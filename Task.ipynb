# %% [markdown]
# str1 = "_ _ _ my name is shubhangi _ _ _"
# find the len of shubhangi

# %%
str1 = input("Enter string")
print(str1)

str2 = str1.strip().split()

temp = str2[-1]

print(len(temp))
# Out:
# this is string
# 6

# %% [markdown]
# str1 = abccc
# add ccc in the front of str

# %%
str1 = input("Enter String")
print(str1)

list1 = []
list2 = []

temp = str1[-1]

for i in str1:
    if i == temp:
        list1.append(i)
    else:
        list2.append(i)


list3 = list1 + list2
print("".join(list3))
# Out:
# abbccc
# cccabb

# %% [markdown]
# if
# str = abcdefghijkl
# then group of 4 char and reverse it otherwise print string as it is

# %%
str1 = input("Enter string")
print(str1)

if len(str1) % 4 == 0:
    for i in range(0,len(str1), 4):
        print(str1[i:i+4][::-1], end=" ")
else:
    print(str1)
# Out:
# abcdxyxy
# dcba yxyx

# %% [markdown]
# str = python
# then last two char is on
# then display ononon

# %%
str1 = input("Enter string")
print(str1)

str2 = str1[-2: ]
print("Last char of string: ",str2)

if len(str1) % 2 == 0:
    str3 = str2 * (len(str1)//2)  
    print(str3)
else:
    str4 = (str2 * (len(str1)//2)) + str2[0]
    print(str4)
# Out:
# pytho
# Last char of string:  ho
# hohoh

# %%
str1 = "Pytho"
str2 = " "

res = str1[-2: ]

if len(str1) % 2 == 0:
    for i in range(len(str1)//2):
        str2 += res
    print(str2)
else:
    for i in range(len(str1)//2+1):
        str2 += res
    print(str2)
# Out:
#  hohoho

# %% [markdown]
# demo("[[]]","abc")
#
# o/p = [[abc]]

# %%
def demo(s, value):

    return s[:2]+ value + s[2:]

result = demo("[[]]","abc")
print(result)
# Out:
# [[abc]]

# %% [markdown]
# str1 = "my name is and my friend name is abc"
# remove duplicate
# create list
# arenge it in alphabatical order

# %%
str1 = "My name is Shubhangi and My friend name is Divya"

set1 = set(str1)

set2 = sorted(set1)
print(set2)
# Out:
# [' ', 'D', 'M', 'S', 'a', 'b', 'd', 'e', 'f', 'g', 'h', 'i', 'm', 'n', 'r', 's', 'u', 'v', 'y']

# %%
list1 = [2, 3, 4, 3, 2, 1, 5]

higher = 0
higher_count = 0

for i in list1:
    higher_count =
