# %% [markdown]
# 4. Write a program to create a new tuple containing only positive numbers from a
# given tuple.

# %%
tup1 = (2, 3, 4, 7, 9 ,4 ,6)

tup2 = ()
for i in tup1:
    if i > 0:
        tup2 += (i, )
print("Positive numbers in the tuple :",tup2)
# Out:
# Positive numbers in the tuple : (2, 3, 4, 7, 9, 4, 6)
