# %% [markdown]
# 2. Write a program to count the number of even and odd numbers in a tuple.

# %%
tup1 = (2, 3, 4, 7, 9 ,4 ,6)

even = 0
odd = 0

for i in tup1:
    if i % 2 == 0:
        even += 1
    else:
        odd += 1

print("Count of the even numbers :", even)
print("Count of the odd numbers :", odd)
# Out:
# Count of the even numbers : 4
# Count of the odd numbers : 3
