# %% [markdown]
# 8. Write a program to find the sum of all values in a dictionary.
# - {'Math':85, 'Science':90, 'English':80}
#
# - Output:
# - 255

# %%
dict1 = {'Math': 85, 'Science': 90, 'English': 80}

total = sum(dict1.values())

print(total)
# Out:
# 255
