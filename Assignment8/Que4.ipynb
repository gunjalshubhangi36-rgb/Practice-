# %% [markdown]
# 4. Write a program to find the key having the minimum value in a dictionary.

# %%
Dict1 = {'A':85, 'B':92, 'C':78}

print("The key having the minimum value in a dictionar :")
print(min(Dict1, key = Dict1.get))
# Out:
# The key having the minimum value in a dictionar :
# C
