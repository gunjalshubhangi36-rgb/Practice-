# %% [markdown]
# 4. Predict the output before running the program, then verify.

# %%
a = 10
b = 20
print(a + b * 2)        #50
print((a + b) * 2)      #60
print(a ** 2 + b)       #120
print(a // 3)           #9       
print(a / 3)            #3.3
# Out:
# 50
# 60
# 120
# 3
# 3.3333333333333335
