# %%
print(5 == 5.0)
print(5 is 5.0)
# Out:
# True
# False
# <>:2: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\Shri Rokdeshwar\AppData\Local\Temp\ipykernel_1848\2397774952.py:2: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(5 is 5.0)
