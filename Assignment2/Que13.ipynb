# %%
a = [10,20]
b = a
c = [10,20]
print(a == b)                  #ture
print(a is b)                  #true
print(a == c)                  #true
print(a is c)                  #false
print(id(a))
print(id(b))
print(id(c))
# Out:
# True
# True
# True
# False
# 2074251356544
# 2074251356544
# 2074251356288
