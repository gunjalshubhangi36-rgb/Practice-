# %% [markdown]
# 5. Write a program to remove all duplicate characters from a string while maintaining their
# original order.
# - Input : programming
# - Output : progamin

# %%
string = input("Enter a string: ")

result = ""

for i in string:
    if i not in result:
        result = result + i

print("Output:", result)
# Out:
# Output: Shubangi
