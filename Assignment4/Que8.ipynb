# %% [markdown]
# 8. Write a program to count the total number of words in a sentence without using the
# split() method.
# - Input: Python is easy to learn
# - Output: 5

# %%
Str1 = input("Enter string")

count = 1
space =" "

for i in Str1:
    if i.startswith(" "):
        count += 1
print("count of the words : ",count)
# Out:
# 3
