# %%
Student_name = "Demo"

Student_info = """I am shubhangi santosh gunjal
Iam from pune."""                     #multiple line input 

print(Student_name)
print(Student_info)
# Out:
# Demo
# I am shubhangi santosh gunjal
# Iam from pune.

# %% [markdown]
# Immutable

# %%
user_Name = "demo"

print(user_Name)
print(id(user_Name))

user_Name = "user"          #here update string because it is in differet memory location

print(user_Name)
print(id(user_Name))
# Out:
# demo
# 2360472918640
# user
# 2360399822784

# %% [markdown]
# Indexing = access element using index

# %%
user_Name = "demo"

print(user_Name[2])
# Out:
# m

# %% [markdown]
# slicing support

# %%
user_Name = "Demouser"

print(user_Name[0:4])
print(user_Name[0:4:2])                     #skip the element which is in the 3rd index
print(user_Name[0:])                        #starting with 0 up to last
print(user_Name[:4])                        #assume from ) index
print(user_Name[:])   
print(user_Name[::-1])   
                  #print whole string
# Out:
# Demo
# Dm
# Demouser
# Demo
# Demouser
# resuomeD

# %% [markdown]
# Iteration

# %%
user_Name ="Demouser"

temp = (user_Name[::-1])

for i in user_Name:
    print(temp)
    print(i)
# Out:
# resuomeD
# D
# resuomeD
# e
# resuomeD
# m
# resuomeD
# o
# resuomeD
# u
# resuomeD
# s
# resuomeD
# e
# resuomeD
# r

# %% [markdown]
# homogeneous hetrogeneous

# %%
UserName = "demouser123"

print (UserName)
#print (UserName[10] + 3)                       #homogeneous can be assign as a string

listOne = ["demo",True,3]
print(listOne[2] + 3)                            #hetrogeneous it can be take as a integer
# Out:
# demouser123
# 6

# %% [markdown]
# Positive and negative indexing

# %%
UserName = "demouser"

#           01234567
#           -5-4-3-2-1


print(UserName[7])             #positive indexing
print(UserName[-2])            #negative indeing
# Out:
# r
# e

# %% [markdown]
# concatnation

# %%
str1 = "demo"
str2 = "user"

fullName = str1 + str2
print(fullName)
# Out:
# demouser

# %% [markdown]
# Sring Methods

# %%
str1 = "My NAME is shubhangi santosh gunjal."
temp = "     demo"

print(str1.upper())
print(str1.lower())
print(str1.capitalize())  #first leter capital of sentence
print(str1.title())       #each word first leter capital
print(str1.swapcase())    #reversed 

print(str1)
print(temp)

print("remove left side space: ",temp.lstrip())           #remove left side space
print("remove right side space: ",temp.rstrip())           #remove rigth side space
print("remove both side space: ",temp.strip())            #remove both side space
# Out:
# MY NAME IS SHUBHANGI SANTOSH GUNJAL.
# my name is shubhangi santosh gunjal.
# My name is shubhangi santosh gunjal.
# My Name Is Shubhangi Santosh Gunjal.
# mY name IS SHUBHANGI SANTOSH GUNJAL.
# My NAME is shubhangi santosh gunjal.
#      demo
# remove left side space:  demo
# remove right side space:       demo
# remove both side space:  demo

# %%
str1 = "Demo"

print(str1)

print(str1.replace("e","z"))  #replace all same char in string
# Out:
# Demo
# Dzmo

# %%
str1 = "Demo user live in pune"
str2 = "My Name, is Shubhangi"

print(str1.split())
print(str2.split(","))
# Out:
# ['Demo', 'user', 'live', 'in', 'pune']
# ['My Name', ' is Shubhangi']

# %% [markdown]
# Join

# %%
ListOne = ['Demo', 'user', 'live', 'in', 'pune', "1"]
temp = " ".join(ListOne)
print(temp)
print(" ".join(ListOne))
print(len(ListOne))
print(len(temp))
# Out:
# Demo user live in pune 1
# Demo user live in pune 1
# 6
# 24

# %% [markdown]
# Find the element and index

# %%
demo = "Demo user live in pune"

print(demo.find("o"))
print(demo.index("e"))

print(demo.find("z"))            # write -1
print(demo.index("z"))           # write error
# Out:
# 3
# 1
# -1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 7
#       4 print(demo.index("e"))
#       6 print(demo.find("z"))
# ----> 7 print(demo.index("z"))
#
# ValueError: substring not found

# %%
str1 = "DemoUser"
str2 ="1234"
str3 ="Demo1"

print(str1.count("e"))

print(str1.startswith("D"))  

print(str1.endswith("r"))

print(str1.isalpha())    #complete alpha

print(str2.isdigit())    #complete digit

print(str3.isalnum())    #numbers and digit
# Out:
# 2
# True
# True
# True
# True
# True

# %% [markdown]
# Built-in Funaction

# %%
str1 = "demo"
str2 = "8750934"

#funname(variable)

print(len(str1))     #find lenght
print(max(str2))     #find maximum value

print(ord("d"),ord("e"),ord("m"),ord("o"))      #char to ascci value

print(chr(100), chr(101), chr(109), chr(111))      # ascci to char 

print(max(str1))
# Out:
# 4
# 9
# 100 101 109 111
# d e m o
# o

# %%
str1 = "8750934"
str2 = "demo"
str3 = "shubha0"

print(sorted(str2))

print(type(str1))
print(type(str2))

print(list(str1))

print(tuple(str1))

print(set(str1))



for i ,j in enumerate(str2):
    print(i,j)

print("".join(reversed(str2)))



print(any(str1))       #chack the value is ture or false id any value is true then true

print(any(str3))

print(all(str1))       #ture if all values are true
# Out:
# ['d', 'e', 'm', 'o']
# <class 'str'>
# <class 'str'>
# ['8', '7', '5', '0', '9', '3', '4']
# ('8', '7', '5', '0', '9', '3', '4')
# {'3', '4', '5', '0', '7', '8', '9'}
# 0 d
# 1 e
# 2 m
# 3 o
# omed
# True
# True
# True

# %%
listOne = ["demo", 0]
listtwo = [False, 0 ]
listthree = ["demo", "shubh"]

print(any(listOne))
print(all(listOne))

print(any(listtwo))
print(all(listthree))
# Out:
# True
# False
# False
# True
