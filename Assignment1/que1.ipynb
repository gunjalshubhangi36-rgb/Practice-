# %% [markdown]
# Write a Python program to store the following information using variables and display it in a
# well-formatted way.
# • Name
# • Age
# • College Name
# • City
# • Course Name

# %%
Student_name = "Shuhangi"
Age = 20
Clg_name = "SVCET"
city = "Pune"
Course = "BE Computer"

print("Student Name:", Student_name)
print("Age:", Age)
print("College Name:", Clg_name)
print("City:", city)
print("Course:", Course)
