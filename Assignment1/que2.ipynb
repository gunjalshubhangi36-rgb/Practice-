# %% [markdown]
# Create variables for the following student details and print them:
# • Student Name
# • Roll Number
# • Branch
# • Percentage
# • Passed (True/False)

# %%
std_name = "Shubhangi"
roll_no = 12345
Branch = "BE Computer"
Percentege = 9.5
passed = True

print("Student Name:", std_name)
print("Roll Number:", roll_no)
print("Branch:", Branch)
print("Percentage:", Percentege)
print("Passed:", passed)
# Out:
# Student Name: Shubhangi
# Roll Number: 12345
# Branch: BE Computer
# Percentage: 9.5
# Passed: True
