# %% [markdown]
# 1. Write a Python program to store the following information using variables and display it in a
# well-formatted way.
# • Name
# • Age
# • College Name
# • City
# • Course Name

# %%
Student_name = "Shuhangi"
Age = 20
Clg_name = "SVCET"
city = "Pune"
Course = "BE Computer"

print("Student Name:", Student_name)
print("Age:", Age)
print("College Name:", Clg_name)
print("City:", city)
print("Course:", Course)

# %% [markdown]
# 2. Create variables for the following student details and print them:
# • Student Name
# • Roll Number
# • Branch
# • Percentage
# • Passed (True/False)

# %%
std_name = "Shubhangi"
roll_no = 12345
Branch = "BE Computer"
Percentege = 9.5
passed = True

print("Student Name:", std_name)
print("Roll Number:", roll_no)
print("Branch:", Branch)
print("Percentage:", Percentege)
print("Passed:", passed)

# %% [markdown]
# Q3. Identifier Practice
# Create 10 valid identifiers related to a college management system (for example:
# student_name, roll_no, etc.) and assign appropriate values to them.
# Then print all the variables.

# %%
student_name = "Shubhangi Gunjal"
roll_no = 101
department = "Computer Science"
semester = 5
college_name = "Sahyadri Valley College of Engineering"
age = 21
mobile_number = "9876543210"
email_id = "shubhangi@example.com"
cgpa = 8.75
attendance_percentage = 92.5

# %% [markdown]
# Q4. Comments Practice
# Write a Python program that contains:
# • At least 3 single-line comments
# • 1 multi-line comment
# • A program that prints a short introduction about yourself

# %%
Std_name = "Shubhangi"
roll_no = 123
clg_name = "SVCET"
branch = "Be Computer"
percentage = 85.5
City = "Pune"
Hobbies = ["Reading", "Traveling", "Cooking"]
Stranth = "Hardworking"
Weekness = "Can not indroduce myself in front of new people"

"""In this code, we are storing the introduction of a student in different variables 
and then printing them on the screen."""

print("Student Name:", Std_name)          # The variable names should be meaningful
print("Roll Number:", roll_no)            # Roll number is a unique identifier for each student
print("College Name:", clg_name)
print("Branch:", branch)
print("Percentage:", percentage)          # The percentage is a measure of the student's academic performance
print("City:", City)
print("Hobbies:", Hobbies)
print("Strength:", Stranth)
print("Weakness:", Weekness)

# %% [markdown]
# Q5. Correct the Errors
# Rewrite the following invalid variable names into valid Python identifiers and assign
# appropriate values to them.
# • 2student
# • student-name
# • student name
# • class
# • for
# • employee@id

# %%
student2 = "Divya"
student_name = "Shubhangi"
class_name = "Be Computer"
for_loop = 0
employee_id = 123

print("Student Name:", student_name)
print("Class Name:", class_name)
print("Employee ID:", employee_id)
print("For Loop Value:", for_loop)
print("Student 2 Name:", student2)
