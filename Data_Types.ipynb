# %%
#Number

std_roll = 55
stud_per = 80.60
comp = 10+5j

# String

Student_name = "John Doe"
stud_suename  = 'gunjal'
student_info = '''student name is John Doe
                  student surname is gunjal'''

#boolean

isStudentPercentage = True
isStudentPercentage = False

#Nothing
user_name = None

# %%
roll_no = 55
print("Roll number is: ", roll_no)
print(id(roll_no))

roll_no = 66
print("Roll number is: ", roll_no)
# Out:
# Roll number is:  55
# 140737007561320
# Roll number is:  66

# %%
percentsge = 80.50

temp = int (percentsge)

print(temp)
# Out:
# 80

# %%
#Implicit type conversion

num1 = 10
num2 = 20.5

result = num1 + num2

print("Result is: ", result)
# Out:
# Result is:  30.5

# %%
num1 = "10"
num2 = "20"

temp1= int(num1)
temp2= int(num2)

result = temp1 + temp2

print("Result is: ", result)

result = num1 + num2

print("Result is: ", result)
# Out:
# Result is:  30
# Result is:  1020
